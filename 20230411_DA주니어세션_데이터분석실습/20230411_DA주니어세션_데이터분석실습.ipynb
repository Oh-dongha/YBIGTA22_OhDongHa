# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = 'http://apis.data.go.kr/1741000/DisasterMsg3/getDisasterMsg1List'
params ={'serviceKey' : 'GIRC8vt78Gi+us+cf+s7wlmtyH5483WMW+IY6RrNJBG8mHB9zO+9RYXdfpvno2wacxh7Dn02KpVkiey44TFIFw==', 'pageNo' : '1', 'numOfRows' : '100', 'type' : 'xml' }

df = pd.DataFrame(columns=['create_date', 'location_name', 'msg'])
response = requests.get(url, params=params)
data=response.content
soup = BeautifulSoup(data, "html.parser")

k=0
for item in soup.findAll("row"):
        df.loc[k] = [item.create_date.text, item.location_name.text, item.msg.text]
        k=k+1
df.to_csv('./20230411_DA주니어세션_데이터분석실습.csv',encoding='utf-8-sig')
print(df.head(10))
# Out:
#            create_date                                      location_name  \
# 0  2023/04/30 21:01:12                                           충청북도 보은군
# 1  2023/04/30 19:57:30                                           충청북도 옥천군
# 2  2023/04/30 19:06:42  경상북도 전체,대구광역시 전체,대전광역시 전체,전라북도 전체,충청남도 전체,충청북도...
# 3  2023/04/30 17:00:16                                           경상남도 통영시
# 4  2023/04/30 10:03:29
# 5  2023/04/30 08:36:13                                          부산광역시 기장군
# 6  2023/04/30 08:17:05                                            경기도 파주시
# 7  2023/04/30 08:16:35
# 8  2023/04/29 22:53:59                                           충청북도 보은군
# 9  2023/04/29 21:24:19                                           충청북도 보은군
#
#                                                  msg
# 0  [보은군청] 4월30일 19:03 옥천군 지진발생에 따른 피해 발생시 신고바람. 여...
# 1  [옥천군] 4월 30일 19:03 충북 옥천군 동쪽 16km 지역 규모 3.1 지진...
# 2  [기상청]04월30일19:03 충북 옥천군 동쪽 16km 지역 규모3.1 지진발생/...
# ...
